# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
WHR = pd.read_csv('data/world_happiness_report.csv')
WHR.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
# 국가별로 피벗테이블 작성
Country_g = pd.pivot_table(WHR, index = ('Country name','year'))
Country_g
# Out:
#                    Freedom to make life choices  Generosity  \
# Country name year
# Afghanistan  2008                         0.718       0.168
#              2009                         0.679       0.190
#              2010                         0.600       0.121
#              2011                         0.496       0.162
#              2012                         0.531       0.236
# ...                                         ...         ...
# Zimbabwe     2016                         0.733      -0.095
#              2017                         0.753      -0.098
#              2018                         0.763      -0.068
#              2019                         0.632      -0.064
#              2020                         0.643      -0.009
#
#                    Healthy life expectancy at birth  Life Ladder  \
# Country name year
# Afghanistan  2008                             50.80        3.724
#              2009                             51.20        4.402
# ...

# %%
Country_list = WHR['Country name'].unique().tolist()

# %%
# 데이터 레코드가 6개 이상인 국가만 추출
sum = 0
preprocess = []
for i in Country_list:
    if len(i) <= 5 :
        pass
    else:
        #Country_g.loc[[i]]
        print(i)
        preprocess.append(i)
        sum += 1
        
print(sum)
print(preprocess)
# Out:
# Afghanistan
# Albania
# Algeria
# Angola
# Argentina
# Armenia
# Australia
# Austria
# Azerbaijan
# Bahrain
# Bangladesh
# Belarus
# Belgium
# Belize
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Brazil
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia
# Cameroon
# Canada
# Central African Republic
# Colombia
# Comoros
# Congo (Brazzaville)
# Congo (Kinshasa)
# Costa Rica
# Croatia
# Cyprus
# Czech Republic
# Denmark
# Djibouti
# Dominican Republic
# Ecuador
# El Salvador
# Estonia
# Ethiopia
# Finland
# France
# Gambia
# Georgia
# Germany
# Greece
# Guatemala
# Guinea
# Guyana
# Honduras
# Hong Kong S.A.R. of China
# Hungary
# Iceland
# Indonesia
# Ireland
# Israel
# Ivory Coast
# Jamaica
# Jordan
# Kazakhstan
# Kosovo
# Kuwait
# Kyrgyzstan
# Latvia
# Lebanon
# Lesotho
# Liberia
# Lithuania
# Luxembourg
# Madagascar
# Malawi
# Malaysia
# Maldives
# Mauritania
# Mauritius
# Mexico
# Moldova
# Mongolia
# Montenegro
# Morocco
# Mozambique
# Myanmar
# Namibia
# Netherlands
# ...

# %%
# 각 컬럼별 결측치 확인
Country_g.isnull().sum()
# Out:
# Freedom to make life choices         32
# Generosity                           89
# Healthy life expectancy at birth     55
# Life Ladder                           0
# Log GDP per capita                   36
# Negative affect                      16
# Perceptions of corruption           110
# Positive affect                      22
# Social support                       13
# dtype: int64

# %%
Country_g['Log GDP per capita'].isnull()
# Out:
# Country name  year
# Afghanistan   2008    False
#               2009    False
#               2010    False
#               2011    False
#               2012    False
#                       ...
# Zimbabwe      2016    False
#               2017    False
#               2018    False
#               2019    False
#               2020    False
# Name: Log GDP per capita, Length: 1949, dtype: bool

# %%
# Log GDP per capita 결측치 처리 => 결측치 전년도 다음년도 평균으로 대체
Country_g['Log GDP per capita'].fillna()
# Out:
# 36

# %%
# Social support 결측치 처리 => 결측치 전년도 다음년도 평균으로 대체
